# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached xgboost-1.6.2-py3-none-win_amd64.whl.metadata (1.8 kB)
# ...
#   Using cached pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached hvplot-0.10.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached panel-1.4.4-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached bokeh-3.4.2-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached param-2.1.1-py3-none-any.whl.metadata (7.2 kB)
# ...
# Using cached autoviz-0.1.905-py3-none-any.whl (67 kB)
# Using cached hvplot-0.10.0-py3-none-any.whl (155 kB)
# ...

# %%
df.to_csv('tips')

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

filename="automated eda learning/tips"
sep=","
dft = AV.AutoViz(
    filename,
    sep=",",            # Separator used in the CSV file
    depVar="",          # Set dependent variable if any, otherwise leave as empty string
    dfte=None,          # If no DataFrame is passed, it will read from the file
    header=0,           # Row number to use as column names
    verbose=2,          # Output verbosity level
    lowess=False,       # If you want to smooth the line graphs
    chart_format="png", # Format of the plots
    max_rows_analyzed=150000, # Maximum number of rows to be analyzed
    max_cols_analyzed=30,     # Maximum number of columns to be analyzed
    save_plot_dir=None  # Directory to save the plots
)
# Out:
#     Filename is an empty string or file not able to be loaded
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4 filename="automated eda learning/tips"
#       5 sep=","
# ----> 6 dft = AV.AutoViz(
#       7     filename,
#       8     sep=",",            # Separator used in the CSV file
#       9     depVar="",          # Set dependent variable if any, otherwise leave as empty string
#      10     dfte=None,          # If no DataFrame is passed, it will read from the file
#      11     header=0,           # Row number to use as column names
#      12     verbose=2,          # Output verbosity level
#      13     lowess=False,       # If you want to smooth the line graphs
#      14     chart_format="png", # Format of the plots
#      15     max_rows_analyzed=150000, # Maximum number of rows to be analyzed
# ...
