# %%
#importing the necessary libararies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_profiling import  ProfileReport

# %%
src_data=pd.read_csv('Housing.csv')
src_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
src_data.sum().isna() #checked for any na values
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# prefarea            False
# furnishingstatus    False
# dtype: bool

# %%
#performing label endoing for categorical variables
from sklearn.preprocessing import LabelEncoder

lc=LabelEncoder()

for col in src_data.columns:
    if src_data[col].dtype=='object':
        src_data[col]=lc.fit_transform(src_data[col])

src_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
#performing automated eda using pandaS_profiling

profile=ProfileReport(src_data, explorative=True, dark_mode=True)
profile.to_file('eda_report.html')
# Out:
# C:\Users\Piyush\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
src_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
src_data=src_data.drop(columns=['basement', 'furnishingstatus', 'hotwaterheating'])

# %%
src_data=src_data.drop(columns=['prefarea'])

# %%
src_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    airconditioning  parking
# 0                1        2
# 1                1        3
# 2                0        2
# 3                1        3
# 4                1        2

# %%
x_train_improvement=src_data.drop(columns=['price', 'mainroad'])
x_train_improvement.head()
# Out:
#    area  bedrooms  bathrooms  stories  guestroom  airconditioning  parking
# 0  7420         4          2        3          0                1        2
# 1  8960         4          4        4          0                1        3
# 2  9960         3          2        2          0                0        2
# 3  7500         4          2        2          0                1        3
# 4  7420         4          1        2          1                1        2

# %%
#performing automated eda using pandaS_profiling

profile=ProfileReport(src_data, explorative=True, dark_mode=True)
profile.to_file('eda_report01.html')
# Out:
# C:\Users\Piyush\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Random Forest model
rf = RandomForestRegressor(random_state=42)

# Feature importance
rf.fit(x_train_improvement, y_train)
feature_importances = pd.Series(rf.feature_importances_, index=x.columns)
print(feature_importances.sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       2 rf = RandomForestRegressor(random_state=42)
#       4 # Feature importance
# ----> 5 rf.fit(x_train_improvement, y_train)
#       6 feature_importances = pd.Series(rf.feature_importances_, index=x.columns)
#       7 print(feature_importances.sort_values(ascending=False))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
#splititng into dependent and independent features
x=src_data.drop('price', axis=1)
y=src_data['price']

print("independent features")
x.head()
print("dependent features")
y.head()
# Out:
# independent features
# dependent features
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
#doing feature scaling for optimal results
from sklearn.preprocessing import StandardScaler
std_scl=StandardScaler()
x_scaled=std_scl.fit_transform(x)

# %%
#splitting dataset into train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x_scaled, y, test_size=0.75, random_state=32)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Initialize and train the RandomForestRegressor with GridSearchCV for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search=GridSearchCV(estimator=RandomForestRegressor(random_state=42), param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              verbose=2)

# %%
# Predict and evaluate the model
from sklearn.metrics import mean_squared_error

best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Mean Squared Error: {mse}")
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Mean Squared Error: 1620278172377.4731
